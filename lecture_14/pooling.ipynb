# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
def apply_pool(img, pool):
    res = np.zeros([img.shape[0]//pool[0], img.shape[1]//pool[1]])
    for r in range(res.shape[0]):
        for c in range(res.shape[1]):
            cut = img[r*pool[0]:r*pool[0]+pool[0], c*pool[1]:c*pool[1]+pool[1]]
            res[r][c] = np.max(cut)
    
    return res

# %%
img = cv2.imread("../lecture_07/strange.jpg")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
small = cv2.resize(gray, (gray.shape[1]//2, gray.shape[0]//2))

# %%
out = apply_pool(small, [2, 2])

# %%
fil = np.ones((7, 7), dtype=int)
plt.imshow(apply_filter(small, fil), cmap="gray")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-b57a8a750e27> in <module>
#       1 fil = np.ones((7, 7), dtype=int)
# ----> 2 plt.imshow(apply_filter(small, fil), cmap="gray")
#
# NameError: name 'apply_filter' is not defined

# %%
plt.imshow(small, cmap="gray")

# %%
small.shape
# Out:
# (178, 316)

# %%
out.shape
# Out:
# (89, 158)
